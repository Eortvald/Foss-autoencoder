# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Script that applies the mask from channel 8 to the image and cuts out unnecessary background pixels.
i = 0

# 
# max_h, max_w = get_max_width_height()
max_w = 91
max_h = 265


#Path to root of images
path = 'C:/ASB/Projects/EyefossAutoencoder/Fagprojekt-2021/BlobArchive_v2/'
labels = pd.read_csv('sparse_eyefoss_labels.csv')
df = labels.set_index('Names', drop = False)

#Folder in root directory
folders = os.listdir(path)

#Looping through each folder
for folder in folders:

    #Untill we start working with the whole data set.
    if i > 0:
        break
    #For each folder we scan every entry -> each kernel image.
    with os.scandir('C:/ASB/Projects/EyefossAutoencoder/Fagprojekt-2021/BlobArchive_v2/' + str(folder)) as entries:
        for entry in entries:
            i = i + 1
            
            #Load image
            img = np.load(entry)
            img_copy = img.copy()

            #Applying mask
            mask = img[:,:,7]
            img = np.where(mask[...,None] != 0, img, [0,0,0,0,0,0,0,0])

            #width and height of image
            hei = np.shape(img[:,:,0])[0]
            wid = np.shape(img[:,:,0])[1]
            wdis = np.append(wdis, wid)
            if (hei % 2) == 1:
                rhei1 = (max_h-hei)/2
                rhei2 = (max_h-hei)/2
            elif (hei % 2) == 0:
                rhei1 = (max_h-hei+1)/2
                rhei2 = (max_h-hei-1)/2
            if (wid % 2) == 1:
                rwid1 = (max_w-wid)/2
                rwid2 = (max_w-wid)/2
            elif (wid % 2) == 0:
                rwid1 = (max_w-wid+1)/2
                rwid2 = (max_w-wid-1)/2
            
            
            #Zero padding
            #img = np.pad(img, ((int(rhei2),int(rhei1)), (int(rwid1),int(rwid2)), (0,0)), 'constant')
            print(np.shape(img))
            
            #This is only for plotting.
            '''
            if wid > 88:
                print(i)
            if i == 45:
                print("labels for this image are:", df.loc[(entry.name.split(".")[0]), :])
                pretest = np.dstack((img_copy[:,:,4], img_copy[:,:,2], img_copy[:,:,1]))
                test = np.dstack((img[:,:,4],img[:,:,2],img[:,:,1]))
                fig, ar = plt.subplots(1,3)
                ar[2].imshow(pretest)
                ar[1].imshow(mask)
                ar[0].imshow(test)
                fig.show
            '''    
                
          
            #for saving the edited images
            #np.save(entry, img, allow_pickle = True, fix_imports = False)
# Out:
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# (265, 91, 8)
# ...

# %%
plt.hist(wdis)
# Out:
# (array([  0.,   0.,   0.,   0.,   0., 869.,   0.,   0.,   0.,   0.]),
#  array([90.5, 90.6, 90.7, 90.8, 90.9, 91. , 91.1, 91.2, 91.3, 91.4, 91.5]),
#  <a list of 10 Patch objects>)
